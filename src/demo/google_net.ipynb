# %%
import sys

sys.path.append("..")

# %%
from utils.preprocessing_utils import PreprocessingUtils

# %%
from utils.model_wrapper import ModelWrapper

# %%
preprocessing_utils = PreprocessingUtils()
# Out:
# Files already exist, skipping...
# Loading images and labels...
# Images and labels loaded successfully!
# Preprocessing labels...
# Labels preprocessed successfully!
# Loading split data...
# Split data loaded successfully!

# %%
google_net_wrapper = ModelWrapper("GoogleNet", preprocessing_utils=preprocessing_utils)

# %%
google_net_wrapper.load_model_and_history()
# Out:
# Loading model from "../../artifacts/models/GoogleNet.h5"...
# Model loaded successfully!
# Loading history from "../../artifacts/model_histories/history_GoogleNet"...
# History loaded successfully!

# %%
google_net_wrapper.display_random_image_prediction()
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
google_net_wrapper.display_all_image_predictions_for_label("CAKE")
# Out:
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
