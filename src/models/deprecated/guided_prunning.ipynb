# %%
import os
import random
from typing import Optional

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
from sklearn import preprocessing, model_selection, metrics

# %%
from tensorflow import keras

keras.backend.clear_session()

# %%
RANDOM_SEED = 42

# %%
DATASETS_DIR = "../../../datasets"

ROOT_IMG_DIR = f"{DATASETS_DIR}/images"

ORIGINAL_IMG_DIR = f"{ROOT_IMG_DIR}/original"
TRAIN_IMG_DIR = f"{ROOT_IMG_DIR}/train"
TEST_IMG_DIR = f"{ROOT_IMG_DIR}/test"
VAL_IMG_DIR = f"{ROOT_IMG_DIR}/val"

NUMPY_DIR = f"{DATASETS_DIR}/numpy"

NUMPY_IMG_DIR = f"{NUMPY_DIR}/images.npy"
NUMPY_LABEL_DIR = f"{NUMPY_DIR}/labels.npy"

ARTIFACT_DIR = "../../../artifacts"

# %%
path_to_model = f"{ARTIFACT_DIR}/models/model_guided_pruning.h5"

# %%
def load_and_transform_images():
    if os.path.exists(NUMPY_IMG_DIR) and os.path.exists(NUMPY_LABEL_DIR):
        print("Files already exist, skipping...")
        return

    categories = os.listdir(ORIGINAL_IMG_DIR)

    images = []
    labels = []

    for category in categories:
        image_files = os.listdir(os.path.join(ORIGINAL_IMG_DIR, category))

        for image_file in image_files:
            img = keras.preprocessing.image.load_img(
                os.path.join(ORIGINAL_IMG_DIR, category, image_file), target_size=(256, 256)
            )
            img = keras.preprocessing.image.img_to_array(img)
            img = img / 255.0

            images.append(img)
            labels.append(category)

    images = np.array(images)
    labels = np.array(labels)

    np.save(NUMPY_IMG_DIR, images)
    np.save(NUMPY_LABEL_DIR, labels)


load_and_transform_images()
# Out:
# Files already exist, skipping...

# %%
images = np.load(NUMPY_IMG_DIR)
labels = np.load(NUMPY_LABEL_DIR)

# %%
num_classes = len(np.unique(labels))

# %%
le = preprocessing.LabelEncoder()

labels = le.fit_transform(labels)

labels = keras.utils.to_categorical(labels, num_classes)

# %%
X_train_val, X_test, Y_train_val, Y_test = model_selection.train_test_split(
    images, labels, test_size=1 / 8, random_state=RANDOM_SEED
)

X_train, X_val, Y_train, Y_val = model_selection.train_test_split(
    X_train_val, Y_train_val, test_size=1 / 20, random_state=RANDOM_SEED
)

# %%
def build_model(
    num_conv_layers: int, kernel_sizes: list[tuple[int, int]], conv_filters: list[int], dense_units: int, num_dense: int
):
    conv_layers = [
        [
            keras.layers.Conv2D(
                filters=conv_filters[i],
                kernel_size=kernel_size,
                activation="relu",
                input_shape=images.shape[1:],
            )
            if i == 0
            else keras.layers.Conv2D(
                filters=conv_filters[i],
                kernel_size=kernel_size,
                activation="relu",
            ),
            keras.layers.MaxPooling2D(pool_size=(2, 2)),
            keras.layers.Dropout(0.5),
            keras.layers.BatchNormalization() if i != len(kernel_sizes) - 1 else keras.layers.Flatten(),
        ]
        for i, kernel_size in enumerate(kernel_sizes)
    ]

    dense_layers = [
        [keras.layers.Dense(units=dense_units, activation="relu"), keras.layers.Dropout(0.5)] for _ in range(num_dense)
    ]

    layers = (
        [layer for conv_layer in conv_layers for layer in conv_layer]
        + [layer for dense_layer in dense_layers for layer in dense_layer]
        + [keras.layers.Dense(units=num_classes, activation="softmax")]
    )

    model = keras.models.Sequential(layers=layers)

    model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

    return model

# %%
def train_and_test(model: keras.models.Sequential):
    early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=20)

    history = model.fit(
        X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=500, callbacks=[early_stopping]
    )

    loss, accuracy = model.evaluate(X_test, Y_test)

    return history, loss, accuracy

# %%
def plot_accuracy(history: keras.callbacks.History):
    plt.plot(history.history["accuracy"], label="train accuracy")
    plt.plot(history.history["val_accuracy"], label="validation accuracy")
    plt.title("Model accuracy")
    plt.ylabel("Accuracy")
    plt.xlabel("Epoch")
    plt.legend(loc="best")
    plt.savefig(f"{ARTIFACT_DIR}/plots/Accuracy_GuidedPruning")
    plt.show()


def plot_loss(history: keras.callbacks.History):
    plt.plot(history.history["loss"], label="train loss")
    plt.plot(history.history["val_loss"], label="validation loss")
    plt.title("Model loss")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend(loc="best")
    plt.savefig(f"{ARTIFACT_DIR}/plots/Loss_GuidedPruning")
    plt.show()

# %%
def guided_pruning():
    params = {
        "num_conv_layers": 3,
        "kernel_sizes": [(11, 11), (5, 5), (3, 3)],
        "conv_filters": [3, 16, 96],
        "dense_units": 2048,
        "num_dense": 2,
    }

    goal_acc = 0.9
    accuracy = 0.0
    best_acc = 0
    best_loss = 0
    best_params = params.copy()
    best_history: Optional[keras.callbacks.History] = None
    best_model: Optional[keras.models.Model] = None

    for _ in range(3):  # Limiting to 3 iterations due to OOM error
        if accuracy > goal_acc:
            break

        key = random.choice(list(params.keys()))
        if key == "num_conv_layers":
            num = random.choice([-1, 1])
            if num == -1:
                params["num_conv_layers"] -= 1
                params["kernel_sizes"].pop()
                params["conv_filters"].pop()
            else:
                params["num_conv_layers"] += 1
                params["kernel_sizes"].append((3, 3))
                params["conv_filters"].append(3)
        if key == "kernel_sizes":
            index = random.randint(0, len(params["kernel_sizes"]) - 1)
            num = random.choice([-1, 1])
            if not (params["kernel_sizes"][index][0] <= 2 and num == -1):
                params["kernel_sizes"][index] = (
                    params["kernel_sizes"][index][0] + num,
                    params["kernel_sizes"][index][1] + num,
                )
        if key == "conv_filters":
            index = random.randint(0, len(params["conv_filters"]) - 1)
            num = random.choice([-1, 1])
            if not (params["conv_filters"][index] <= 2 and num == -1):
                params["conv_filters"][index] += num
        if key == "dense_units":
            num = random.choice([-512, 512])
            if not (params["dense_units"] <= 512 and num == -512):
                params["dense_units"] += num
        if key == "num_dense":
            num = random.choice([-1, 1])
            if not (params["num_dense"] <= 2 and num == -1):
                params["num_dense"] += num

        model = build_model(**params)

        print(model.summary())
        print(f"Training model with params {params}")

        history, loss, accuracy = train_and_test(model)

        if accuracy > best_acc:
            best_acc = accuracy
            best_loss = loss
            best_params = params.copy()
            best_history = history
            best_model = model

        print("=============================================")
        print(f"Current Accuracy: {accuracy:.4f} | Best Accuracy: {best_acc:.4f}")
        print(f"Current Loss: {loss:.4f} | Best Loss: {best_loss:.4f}")
        print("=============================================")

        del model

    return best_model, best_history, best_params, best_acc, best_loss

# %%
best_model, best_history, best_params, best_acc, best_loss = guided_pruning()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 246, 246, 3)       1092
#
#  max_pooling2d (MaxPooling2D  (None, 123, 123, 3)      0
#  )
#
#  dropout (Dropout)           (None, 123, 123, 3)       0
#
#  batch_normalization (BatchN  (None, 123, 123, 3)      12
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 119, 119, 16)      1216
#
#  max_pooling2d_1 (MaxPooling  (None, 59, 59, 16)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 59, 59, 16)        0
#
#  batch_normalization_1 (Batc  (None, 59, 59, 16)       64
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 57, 57, 96)        13920
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 96)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 28, 28, 96)        0
#
#  flatten (Flatten)           (None, 75264)             0
#
#  dense (Dense)               (None, 2560)              192678400
#
#  dropout_3 (Dropout)         (None, 2560)              0
#
#  dense_1 (Dense)             (None, 2560)              6556160
#
#  dropout_4 (Dropout)         (None, 2560)              0
#
#  dense_2 (Dense)             (None, 25)                64025
#
# =================================================================
# Total params: 199,314,889
# Trainable params: 199,314,851
# Non-trainable params: 38
# _________________________________________________________________
# None
# Training model with params {'num_conv_layers': 3, 'kernel_sizes': [(11, 11), (5, 5), (3, 3)], 'conv_filters': [3, 16, 96], 'dense_units': 2560, 'num_dense': 2}
# Epoch 1/100
# 9/9 [==============================] - 10s 291ms/step - loss: 18.8431 - accuracy: 0.0511 - val_loss: 3.2187 - val_accuracy: 0.0369
# Epoch 2/100
# 9/9 [==============================] - 2s 203ms/step - loss: 3.3798 - accuracy: 0.0613 - val_loss: 3.2163 - val_accuracy: 0.0369
# Epoch 3/100
# 9/9 [==============================] - 1s 166ms/step - loss: 3.1970 - accuracy: 0.0727 - val_loss: 3.2120 - val_accuracy: 0.0369
# Epoch 4/100
# 9/9 [==============================] - 1s 162ms/step - loss: 3.1642 - accuracy: 0.0752 - val_loss: 3.2065 - val_accuracy: 0.0369
# Epoch 5/100
# 9/9 [==============================] - 1s 160ms/step - loss: 3.1476 - accuracy: 0.0881 - val_loss: 3.2016 - val_accuracy: 0.0599
# Epoch 6/100
# 9/9 [==============================] - 2s 170ms/step - loss: 3.1302 - accuracy: 0.0847 - val_loss: 3.1968 - val_accuracy: 0.0599
# Epoch 7/100
# 9/9 [==============================] - 2s 172ms/step - loss: 3.1240 - accuracy: 0.0907 - val_loss: 3.1919 - val_accuracy: 0.0599
# Epoch 8/100
# 9/9 [==============================] - 2s 172ms/step - loss: 3.1164 - accuracy: 0.0912 - val_loss: 3.1881 - val_accuracy: 0.0599
# Epoch 9/100
# 9/9 [==============================] - 2s 166ms/step - loss: 3.0993 - accuracy: 0.0944 - val_loss: 3.1835 - val_accuracy: 0.0599
# Epoch 10/100
# 9/9 [==============================] - 1s 161ms/step - loss: 3.0962 - accuracy: 0.1014 - val_loss: 3.1796 - val_accuracy: 0.0599
# Epoch 11/100
# 9/9 [==============================] - 1s 161ms/step - loss: 3.0770 - accuracy: 0.1036 - val_loss: 3.1761 - val_accuracy: 0.0599
# Epoch 12/100
# 9/9 [==============================] - 1s 161ms/step - loss: 3.0609 - accuracy: 0.1095 - val_loss: 3.1728 - val_accuracy: 0.0599
# Epoch 13/100
# 9/9 [==============================] - 2s 171ms/step - loss: 3.0446 - accuracy: 0.1121 - val_loss: 3.1699 - val_accuracy: 0.0599
# Epoch 14/100
# 9/9 [==============================] - 2s 171ms/step - loss: 3.0312 - accuracy: 0.1158 - val_loss: 3.1673 - val_accuracy: 0.0599
# Epoch 15/100
# 9/9 [==============================] - 2s 169ms/step - loss: 3.0222 - accuracy: 0.1224 - val_loss: 3.1644 - val_accuracy: 0.0599
# Epoch 16/100
# 9/9 [==============================] - 1s 162ms/step - loss: 3.0149 - accuracy: 0.1262 - val_loss: 3.1628 - val_accuracy: 0.0599
# Epoch 17/100
# 9/9 [==============================] - 1s 161ms/step - loss: 3.0042 - accuracy: 0.1270 - val_loss: 3.1609 - val_accuracy: 0.0599
# Epoch 18/100
# 9/9 [==============================] - 1s 160ms/step - loss: 3.0011 - accuracy: 0.1294 - val_loss: 3.1572 - val_accuracy: 0.0599
# Epoch 19/100
# 9/9 [==============================] - 1s 162ms/step - loss: 2.9676 - accuracy: 0.1352 - val_loss: 3.1543 - val_accuracy: 0.0599
# Epoch 20/100
# 9/9 [==============================] - 2s 171ms/step - loss: 2.9463 - accuracy: 0.1435 - val_loss: 3.1547 - val_accuracy: 0.0599
# Epoch 21/100
# 9/9 [==============================] - 2s 171ms/step - loss: 2.9386 - accuracy: 0.1479 - val_loss: 3.1523 - val_accuracy: 0.0599
# Epoch 22/100
# 9/9 [==============================] - 2s 173ms/step - loss: 2.9287 - accuracy: 0.1489 - val_loss: 3.1521 - val_accuracy: 0.0599
# Epoch 23/100
# 9/9 [==============================] - 1s 164ms/step - loss: 2.9014 - accuracy: 0.1547 - val_loss: 3.1507 - val_accuracy: 0.0599
# Epoch 24/100
# 9/9 [==============================] - 2s 166ms/step - loss: 2.8818 - accuracy: 0.1613 - val_loss: 3.1489 - val_accuracy: 0.0599
# Epoch 25/100
# 9/9 [==============================] - 1s 163ms/step - loss: 2.8477 - accuracy: 0.1698 - val_loss: 3.1494 - val_accuracy: 0.0599
# Epoch 26/100
# 9/9 [==============================] - 2s 169ms/step - loss: 2.8195 - accuracy: 0.1785 - val_loss: 3.1493 - val_accuracy: 0.0599
# Epoch 27/100
# 9/9 [==============================] - 2s 171ms/step - loss: 2.8180 - accuracy: 0.1820 - val_loss: 3.1492 - val_accuracy: 0.0599
# Epoch 28/100
# 9/9 [==============================] - 2s 170ms/step - loss: 2.7877 - accuracy: 0.1929 - val_loss: 3.1498 - val_accuracy: 0.0599
# Epoch 29/100
# 9/9 [==============================] - 2s 167ms/step - loss: 2.7644 - accuracy: 0.1961 - val_loss: 3.1506 - val_accuracy: 0.0599
# Epoch 30/100
# 9/9 [==============================] - 1s 162ms/step - loss: 2.7430 - accuracy: 0.2068 - val_loss: 3.1505 - val_accuracy: 0.0599
# Epoch 31/100
# 9/9 [==============================] - 1s 163ms/step - loss: 2.7040 - accuracy: 0.2141 - val_loss: 3.1530 - val_accuracy: 0.0599
# Epoch 32/100
# 9/9 [==============================] - 1s 162ms/step - loss: 2.6669 - accuracy: 0.2209 - val_loss: 3.1533 - val_accuracy: 0.0599
# Epoch 33/100
# 9/9 [==============================] - 2s 172ms/step - loss: 2.6495 - accuracy: 0.2347 - val_loss: 3.1548 - val_accuracy: 0.0599
# Epoch 34/100
# 9/9 [==============================] - 2s 174ms/step - loss: 2.6081 - accuracy: 0.2435 - val_loss: 3.1567 - val_accuracy: 0.0599
# Epoch 35/100
# 9/9 [==============================] - 2s 174ms/step - loss: 2.6108 - accuracy: 0.2425 - val_loss: 3.1587 - val_accuracy: 0.0599
# Epoch 36/100
# 9/9 [==============================] - 1s 165ms/step - loss: 2.5278 - accuracy: 0.2639 - val_loss: 3.1572 - val_accuracy: 0.0599
# Epoch 37/100
# 9/9 [==============================] - 1s 160ms/step - loss: 2.5541 - accuracy: 0.2610 - val_loss: 3.1580 - val_accuracy: 0.0599
# Epoch 38/100
# 9/9 [==============================] - 1s 160ms/step - loss: 2.4841 - accuracy: 0.2805 - val_loss: 3.1564 - val_accuracy: 0.0599
# Epoch 39/100
# 9/9 [==============================] - 1s 159ms/step - loss: 2.4583 - accuracy: 0.2875 - val_loss: 3.1568 - val_accuracy: 0.0599
# Epoch 40/100
# 9/9 [==============================] - 2s 171ms/step - loss: 2.4455 - accuracy: 0.2951 - val_loss: 3.1598 - val_accuracy: 0.0553
# Epoch 41/100
# 9/9 [==============================] - 2s 173ms/step - loss: 2.4150 - accuracy: 0.2987 - val_loss: 3.1598 - val_accuracy: 0.0599
# Epoch 42/100
# 9/9 [==============================] - 2s 172ms/step - loss: 2.4179 - accuracy: 0.3048 - val_loss: 3.1445 - val_accuracy: 0.0645
# Epoch 43/100
# 9/9 [==============================] - 1s 162ms/step - loss: 2.3450 - accuracy: 0.3165 - val_loss: 3.1521 - val_accuracy: 0.0691
# Epoch 44/100
# 9/9 [==============================] - 1s 162ms/step - loss: 2.2862 - accuracy: 0.3289 - val_loss: 3.1470 - val_accuracy: 0.0691
# Epoch 45/100
# 9/9 [==============================] - 7s 878ms/step - loss: 2.2456 - accuracy: 0.3476 - val_loss: 3.1440 - val_accuracy: 0.0737
# Epoch 46/100
# 9/9 [==============================] - 2s 221ms/step - loss: 2.2113 - accuracy: 0.3505 - val_loss: 3.1432 - val_accuracy: 0.0737
# Epoch 47/100
# 9/9 [==============================] - 2s 205ms/step - loss: 2.1890 - accuracy: 0.3624 - val_loss: 3.1297 - val_accuracy: 0.0645
# Epoch 48/100
# 9/9 [==============================] - 2s 183ms/step - loss: 2.1312 - accuracy: 0.3807 - val_loss: 3.1267 - val_accuracy: 0.0829
# Epoch 49/100
# 9/9 [==============================] - 2s 225ms/step - loss: 2.1040 - accuracy: 0.3851 - val_loss: 3.1263 - val_accuracy: 0.0783
# Epoch 50/100
# 9/9 [==============================] - 2s 227ms/step - loss: 2.0327 - accuracy: 0.4040 - val_loss: 3.1323 - val_accuracy: 0.0553
# Epoch 51/100
# 9/9 [==============================] - 2s 189ms/step - loss: 1.9873 - accuracy: 0.4126 - val_loss: 3.1244 - val_accuracy: 0.0737
# Epoch 52/100
# 9/9 [==============================] - 2s 182ms/step - loss: 2.0090 - accuracy: 0.4194 - val_loss: 3.1087 - val_accuracy: 0.0645
# Epoch 53/100
# 9/9 [==============================] - 2s 178ms/step - loss: 1.9452 - accuracy: 0.4364 - val_loss: 3.1219 - val_accuracy: 0.0783
# Epoch 54/100
# 9/9 [==============================] - 2s 217ms/step - loss: 1.9361 - accuracy: 0.4349 - val_loss: 3.1301 - val_accuracy: 0.0645
# Epoch 55/100
# 9/9 [==============================] - 2s 226ms/step - loss: 1.8695 - accuracy: 0.4481 - val_loss: 3.1186 - val_accuracy: 0.0645
# Epoch 56/100
# 9/9 [==============================] - 2s 215ms/step - loss: 1.7980 - accuracy: 0.4746 - val_loss: 3.1331 - val_accuracy: 0.0737
# Epoch 57/100
# 9/9 [==============================] - 2s 186ms/step - loss: 2.1935 - accuracy: 0.3787 - val_loss: 3.0952 - val_accuracy: 0.1014
# Epoch 58/100
# 9/9 [==============================] - 2s 207ms/step - loss: 1.8669 - accuracy: 0.4610 - val_loss: 3.1326 - val_accuracy: 0.0737
# Epoch 59/100
# 9/9 [==============================] - 2s 194ms/step - loss: 1.7686 - accuracy: 0.4919 - val_loss: 3.1037 - val_accuracy: 0.1060
# Epoch 60/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.7008 - accuracy: 0.5033 - val_loss: 3.1027 - val_accuracy: 0.0922
# Epoch 61/100
# 9/9 [==============================] - 2s 221ms/step - loss: 1.6117 - accuracy: 0.5261 - val_loss: 3.1120 - val_accuracy: 0.0922
# Epoch 62/100
# 9/9 [==============================] - 2s 179ms/step - loss: 1.5924 - accuracy: 0.5359 - val_loss: 3.1096 - val_accuracy: 0.1014
# Epoch 63/100
# 9/9 [==============================] - 2s 177ms/step - loss: 1.5541 - accuracy: 0.5502 - val_loss: 3.0974 - val_accuracy: 0.1060
# Epoch 64/100
# 9/9 [==============================] - 2s 167ms/step - loss: 1.4835 - accuracy: 0.5675 - val_loss: 3.0867 - val_accuracy: 0.1106
# Epoch 65/100
# 9/9 [==============================] - 1s 167ms/step - loss: 1.4505 - accuracy: 0.5765 - val_loss: 3.1244 - val_accuracy: 0.1198
# Epoch 66/100
# 9/9 [==============================] - 2s 169ms/step - loss: 1.3819 - accuracy: 0.5943 - val_loss: 3.1172 - val_accuracy: 0.1198
# Epoch 67/100
# 9/9 [==============================] - 2s 256ms/step - loss: 1.3552 - accuracy: 0.6086 - val_loss: 3.1445 - val_accuracy: 0.1152
# Epoch 68/100
# 9/9 [==============================] - 2s 259ms/step - loss: 1.2796 - accuracy: 0.6298 - val_loss: 3.1332 - val_accuracy: 0.1290
# Epoch 69/100
# 9/9 [==============================] - 2s 253ms/step - loss: 1.2369 - accuracy: 0.6432 - val_loss: 3.1611 - val_accuracy: 0.1382
# Epoch 70/100
# 9/9 [==============================] - 2s 247ms/step - loss: 1.2287 - accuracy: 0.6436 - val_loss: 3.1851 - val_accuracy: 0.1382
# Epoch 71/100
# 9/9 [==============================] - 2s 268ms/step - loss: 1.1775 - accuracy: 0.6633 - val_loss: 3.2168 - val_accuracy: 0.1244
# Epoch 72/100
# 9/9 [==============================] - 2s 269ms/step - loss: 1.1640 - accuracy: 0.6680 - val_loss: 3.2057 - val_accuracy: 0.1198
# Epoch 73/100
# 9/9 [==============================] - 2s 259ms/step - loss: 1.1886 - accuracy: 0.6685 - val_loss: 3.2112 - val_accuracy: 0.1475
# Epoch 74/100
# 9/9 [==============================] - 2s 247ms/step - loss: 1.1457 - accuracy: 0.6740 - val_loss: 3.2389 - val_accuracy: 0.1198
# Epoch 75/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.0660 - accuracy: 0.6933 - val_loss: 3.2571 - val_accuracy: 0.1152
# Epoch 76/100
# 9/9 [==============================] - 2s 195ms/step - loss: 1.0431 - accuracy: 0.7027 - val_loss: 3.2646 - val_accuracy: 0.1198
# Epoch 77/100
# 9/9 [==============================] - 2s 185ms/step - loss: 1.0060 - accuracy: 0.7130 - val_loss: 3.2936 - val_accuracy: 0.1198
# Epoch 78/100
# 9/9 [==============================] - 2s 189ms/step - loss: 0.9729 - accuracy: 0.7203 - val_loss: 3.2962 - val_accuracy: 0.1198
# Epoch 79/100
# 9/9 [==============================] - 2s 172ms/step - loss: 0.9319 - accuracy: 0.7300 - val_loss: 3.3063 - val_accuracy: 0.1244
# Epoch 80/100
# 9/9 [==============================] - 2s 177ms/step - loss: 0.9283 - accuracy: 0.7288 - val_loss: 3.3629 - val_accuracy: 0.1336
# Epoch 81/100
# 9/9 [==============================] - 2s 182ms/step - loss: 0.8853 - accuracy: 0.7465 - val_loss: 3.3829 - val_accuracy: 0.1198
# Epoch 82/100
# 9/9 [==============================] - 2s 183ms/step - loss: 0.8906 - accuracy: 0.7477 - val_loss: 3.4148 - val_accuracy: 0.0922
# Epoch 83/100
# 9/9 [==============================] - 2s 175ms/step - loss: 0.8913 - accuracy: 0.7465 - val_loss: 3.4095 - val_accuracy: 0.1198
# Epoch 84/100
# 9/9 [==============================] - 2s 171ms/step - loss: 0.8133 - accuracy: 0.7599 - val_loss: 3.5011 - val_accuracy: 0.1060
# 20/20 [==============================] - 0s 7ms/step - loss: 3.4386 - accuracy: 0.1260
# =============================================
# Current Accuracy: 0.1260 | Best Accuracy: 0.1260
# Current Loss: 3.4386 | Best Loss: 3.4386
# =============================================
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 246, 246, 3)       1092
#
#  max_pooling2d_3 (MaxPooling  (None, 123, 123, 3)      0
#  2D)
#
#  dropout_5 (Dropout)         (None, 123, 123, 3)       0
#
#  batch_normalization_2 (Batc  (None, 123, 123, 3)      12
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 119, 119, 16)      1216
#
#  max_pooling2d_4 (MaxPooling  (None, 59, 59, 16)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 59, 59, 16)        0
#
#  batch_normalization_3 (Batc  (None, 59, 59, 16)       64
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 57, 57, 96)        13920
#
#  max_pooling2d_5 (MaxPooling  (None, 28, 28, 96)       0
#  2D)
#
#  dropout_7 (Dropout)         (None, 28, 28, 96)        0
#
#  flatten_1 (Flatten)         (None, 75264)             0
#
#  dense_3 (Dense)             (None, 2560)              192678400
#
#  dropout_8 (Dropout)         (None, 2560)              0
#
#  dense_4 (Dense)             (None, 2560)              6556160
#
#  dropout_9 (Dropout)         (None, 2560)              0
#
#  dense_5 (Dense)             (None, 2560)              6556160
#
#  dropout_10 (Dropout)        (None, 2560)              0
#
#  dense_6 (Dense)             (None, 25)                64025
#
# =================================================================
# Total params: 205,871,049
# Trainable params: 205,871,011
# Non-trainable params: 38
# _________________________________________________________________
# None
# Training model with params {'num_conv_layers': 3, 'kernel_sizes': [(11, 11), (5, 5), (3, 3)], 'conv_filters': [3, 16, 96], 'dense_units': 2560, 'num_dense': 3}
# Epoch 1/100
# 9/9 [==============================] - 4s 221ms/step - loss: 21.1840 - accuracy: 0.0489 - val_loss: 3.2190 - val_accuracy: 0.0507
# Epoch 2/100
# 9/9 [==============================] - 2s 200ms/step - loss: 3.4215 - accuracy: 0.0506 - val_loss: 3.2176 - val_accuracy: 0.0599
# Epoch 3/100
# 9/9 [==============================] - 2s 165ms/step - loss: 3.2386 - accuracy: 0.0778 - val_loss: 3.2143 - val_accuracy: 0.0599
# Epoch 4/100
# 9/9 [==============================] - 2s 176ms/step - loss: 3.2134 - accuracy: 0.0752 - val_loss: 3.2090 - val_accuracy: 0.0599
# Epoch 5/100
# 9/9 [==============================] - 1s 163ms/step - loss: 3.2012 - accuracy: 0.0793 - val_loss: 3.2014 - val_accuracy: 0.0599
# Epoch 6/100
# 9/9 [==============================] - 2s 171ms/step - loss: 3.1920 - accuracy: 0.0827 - val_loss: 3.1905 - val_accuracy: 0.0599
# Epoch 7/100
# 9/9 [==============================] - 2s 175ms/step - loss: 3.1758 - accuracy: 0.0788 - val_loss: 3.1764 - val_accuracy: 0.0599
# Epoch 8/100
# 9/9 [==============================] - 2s 172ms/step - loss: 3.1584 - accuracy: 0.0742 - val_loss: 3.1629 - val_accuracy: 0.0599
# Epoch 9/100
# 9/9 [==============================] - 2s 170ms/step - loss: 3.1446 - accuracy: 0.0854 - val_loss: 3.1538 - val_accuracy: 0.0599
# Epoch 10/100
# 9/9 [==============================] - 1s 161ms/step - loss: 3.1362 - accuracy: 0.0890 - val_loss: 3.1443 - val_accuracy: 0.0599
# Epoch 11/100
# 9/9 [==============================] - 1s 160ms/step - loss: 3.1185 - accuracy: 0.0912 - val_loss: 3.1386 - val_accuracy: 0.0599
# Epoch 12/100
# 9/9 [==============================] - 1s 160ms/step - loss: 3.1092 - accuracy: 0.0954 - val_loss: 3.1372 - val_accuracy: 0.0599
# Epoch 13/100
# 9/9 [==============================] - 2s 168ms/step - loss: 3.1035 - accuracy: 0.0968 - val_loss: 3.1361 - val_accuracy: 0.0599
# Epoch 14/100
# 9/9 [==============================] - 2s 170ms/step - loss: 3.0961 - accuracy: 0.1005 - val_loss: 3.1349 - val_accuracy: 0.0599
# Epoch 15/100
# 9/9 [==============================] - 2s 171ms/step - loss: 3.0779 - accuracy: 0.1048 - val_loss: 3.1339 - val_accuracy: 0.0599
# Epoch 16/100
# 9/9 [==============================] - 2s 167ms/step - loss: 3.0623 - accuracy: 0.1087 - val_loss: 3.1344 - val_accuracy: 0.0599
# Epoch 17/100
# 9/9 [==============================] - 1s 159ms/step - loss: 3.0449 - accuracy: 0.1153 - val_loss: 3.1356 - val_accuracy: 0.0599
# Epoch 18/100
# 9/9 [==============================] - 1s 162ms/step - loss: 3.0275 - accuracy: 0.1211 - val_loss: 3.1371 - val_accuracy: 0.0599
# Epoch 19/100
# 9/9 [==============================] - 1s 160ms/step - loss: 3.0140 - accuracy: 0.1209 - val_loss: 3.1381 - val_accuracy: 0.0599
# Epoch 20/100
# 9/9 [==============================] - 2s 175ms/step - loss: 3.0000 - accuracy: 0.1311 - val_loss: 3.1391 - val_accuracy: 0.0599
# Epoch 21/100
# 9/9 [==============================] - 2s 171ms/step - loss: 2.9861 - accuracy: 0.1377 - val_loss: 3.1402 - val_accuracy: 0.0599
# Epoch 22/100
# 9/9 [==============================] - 2s 172ms/step - loss: 2.9633 - accuracy: 0.1404 - val_loss: 3.1386 - val_accuracy: 0.0599
# Epoch 23/100
# 9/9 [==============================] - 1s 165ms/step - loss: 2.9317 - accuracy: 0.1484 - val_loss: 3.1377 - val_accuracy: 0.0599
# Epoch 24/100
# 9/9 [==============================] - 1s 161ms/step - loss: 2.9268 - accuracy: 0.1523 - val_loss: 3.1408 - val_accuracy: 0.0599
# Epoch 25/100
# 9/9 [==============================] - 1s 162ms/step - loss: 2.8986 - accuracy: 0.1615 - val_loss: 3.1404 - val_accuracy: 0.0599
# Epoch 26/100
# 9/9 [==============================] - 1s 163ms/step - loss: 2.8738 - accuracy: 0.1734 - val_loss: 3.1418 - val_accuracy: 0.0599
# Epoch 27/100
# 9/9 [==============================] - 2s 172ms/step - loss: 2.8511 - accuracy: 0.1776 - val_loss: 3.1447 - val_accuracy: 0.0599
# Epoch 28/100
# 9/9 [==============================] - 2s 171ms/step - loss: 2.8262 - accuracy: 0.1846 - val_loss: 3.1466 - val_accuracy: 0.0599
# Epoch 29/100
# 9/9 [==============================] - 2s 171ms/step - loss: 2.7960 - accuracy: 0.1917 - val_loss: 3.1474 - val_accuracy: 0.0599
# Epoch 30/100
# 9/9 [==============================] - 1s 165ms/step - loss: 2.8050 - accuracy: 0.1902 - val_loss: 3.1508 - val_accuracy: 0.0599
# Epoch 31/100
# 9/9 [==============================] - 1s 162ms/step - loss: 2.7824 - accuracy: 0.2034 - val_loss: 3.1495 - val_accuracy: 0.0599
# Epoch 32/100
# 9/9 [==============================] - 1s 164ms/step - loss: 2.7441 - accuracy: 0.2070 - val_loss: 3.1488 - val_accuracy: 0.0599
# Epoch 33/100
# 9/9 [==============================] - 1s 166ms/step - loss: 2.7080 - accuracy: 0.2153 - val_loss: 3.1517 - val_accuracy: 0.0599
# Epoch 34/100
# 9/9 [==============================] - 2s 171ms/step - loss: 2.6739 - accuracy: 0.2294 - val_loss: 3.1534 - val_accuracy: 0.0599
# Epoch 35/100
# 9/9 [==============================] - 2s 170ms/step - loss: 2.6731 - accuracy: 0.2323 - val_loss: 3.1543 - val_accuracy: 0.0599
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1494 - accuracy: 0.0840
# =============================================
# Current Accuracy: 0.0840 | Best Accuracy: 0.1260
# Current Loss: 3.1494 | Best Loss: 3.4386
# =============================================
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 246, 246, 4)       1456
#
#  max_pooling2d_6 (MaxPooling  (None, 123, 123, 4)      0
#  2D)
#
#  dropout_11 (Dropout)        (None, 123, 123, 4)       0
#
#  batch_normalization_4 (Batc  (None, 123, 123, 4)      16
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 119, 119, 16)      1616
#
#  max_pooling2d_7 (MaxPooling  (None, 59, 59, 16)       0
#  2D)
#
#  dropout_12 (Dropout)        (None, 59, 59, 16)        0
#
#  batch_normalization_5 (Batc  (None, 59, 59, 16)       64
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 57, 57, 96)        13920
#
#  max_pooling2d_8 (MaxPooling  (None, 28, 28, 96)       0
#  2D)
#
#  dropout_13 (Dropout)        (None, 28, 28, 96)        0
#
#  flatten_2 (Flatten)         (None, 75264)             0
#
#  dense_7 (Dense)             (None, 2560)              192678400
#
#  dropout_14 (Dropout)        (None, 2560)              0
#
#  dense_8 (Dense)             (None, 2560)              6556160
#
#  dropout_15 (Dropout)        (None, 2560)              0
#
#  dense_9 (Dense)             (None, 2560)              6556160
#
#  dropout_16 (Dropout)        (None, 2560)              0
#
#  dense_10 (Dense)            (None, 25)                64025
#
# =================================================================
# Total params: 205,871,817
# Trainable params: 205,871,777
# Non-trainable params: 40
# _________________________________________________________________
# None
# Training model with params {'num_conv_layers': 3, 'kernel_sizes': [(11, 11), (5, 5), (3, 3)], 'conv_filters': [4, 16, 96], 'dense_units': 2560, 'num_dense': 3}
# Epoch 1/100
# 9/9 [==============================] - 4s 235ms/step - loss: 35.9970 - accuracy: 0.0448 - val_loss: 3.2198 - val_accuracy: 0.0461
# Epoch 2/100
# 9/9 [==============================] - 2s 212ms/step - loss: 3.2592 - accuracy: 0.0465 - val_loss: 3.2182 - val_accuracy: 0.0783
# Epoch 3/100
# 9/9 [==============================] - 2s 184ms/step - loss: 3.2247 - accuracy: 0.0552 - val_loss: 3.2165 - val_accuracy: 0.0783
# Epoch 4/100
# 9/9 [==============================] - 2s 179ms/step - loss: 3.2190 - accuracy: 0.0613 - val_loss: 3.2145 - val_accuracy: 0.0783
# Epoch 5/100
# 9/9 [==============================] - 2s 173ms/step - loss: 3.2152 - accuracy: 0.0623 - val_loss: 3.2121 - val_accuracy: 0.0783
# Epoch 6/100
# 9/9 [==============================] - 2s 168ms/step - loss: 3.2158 - accuracy: 0.0594 - val_loss: 3.2093 - val_accuracy: 0.0783
# Epoch 7/100
# 9/9 [==============================] - 2s 169ms/step - loss: 3.2120 - accuracy: 0.0569 - val_loss: 3.2058 - val_accuracy: 0.0783
# Epoch 8/100
# 9/9 [==============================] - 2s 172ms/step - loss: 3.2067 - accuracy: 0.0615 - val_loss: 3.2012 - val_accuracy: 0.0783
# Epoch 9/100
# 9/9 [==============================] - 2s 179ms/step - loss: 3.2023 - accuracy: 0.0606 - val_loss: 3.1949 - val_accuracy: 0.0691
# Epoch 10/100
# 9/9 [==============================] - 2s 179ms/step - loss: 3.1958 - accuracy: 0.0613 - val_loss: 3.1860 - val_accuracy: 0.0691
# Epoch 11/100
# 9/9 [==============================] - 2s 177ms/step - loss: 3.1880 - accuracy: 0.0739 - val_loss: 3.1745 - val_accuracy: 0.0599
# Epoch 12/100
# 9/9 [==============================] - 2s 169ms/step - loss: 3.1791 - accuracy: 0.0696 - val_loss: 3.1622 - val_accuracy: 0.0599
# Epoch 13/100
# 9/9 [==============================] - 2s 171ms/step - loss: 3.1708 - accuracy: 0.0737 - val_loss: 3.1509 - val_accuracy: 0.0599
# Epoch 14/100
# 9/9 [==============================] - 2s 170ms/step - loss: 3.1656 - accuracy: 0.0742 - val_loss: 3.1430 - val_accuracy: 0.0599
# Epoch 15/100
# 9/9 [==============================] - 2s 180ms/step - loss: 3.1646 - accuracy: 0.0747 - val_loss: 3.1404 - val_accuracy: 0.0599
# Epoch 16/100
# 9/9 [==============================] - 2s 180ms/step - loss: 3.1622 - accuracy: 0.0747 - val_loss: 3.1374 - val_accuracy: 0.0599
# Epoch 17/100
# 9/9 [==============================] - 2s 183ms/step - loss: 3.1634 - accuracy: 0.0749 - val_loss: 3.1380 - val_accuracy: 0.0599
# Epoch 18/100
# 9/9 [==============================] - 2s 175ms/step - loss: 3.1629 - accuracy: 0.0742 - val_loss: 3.1376 - val_accuracy: 0.0599
# Epoch 19/100
# 9/9 [==============================] - 2s 171ms/step - loss: 3.1628 - accuracy: 0.0766 - val_loss: 3.1377 - val_accuracy: 0.0599
# Epoch 20/100
# 9/9 [==============================] - 2s 172ms/step - loss: 3.1617 - accuracy: 0.0747 - val_loss: 3.1366 - val_accuracy: 0.0599
# Epoch 21/100
# 9/9 [==============================] - 2s 177ms/step - loss: 3.1622 - accuracy: 0.0747 - val_loss: 3.1359 - val_accuracy: 0.0599
# Epoch 22/100
# 9/9 [==============================] - 2s 184ms/step - loss: 3.1607 - accuracy: 0.0732 - val_loss: 3.1357 - val_accuracy: 0.0599
# Epoch 23/100
# 9/9 [==============================] - 2s 181ms/step - loss: 3.1637 - accuracy: 0.0742 - val_loss: 3.1359 - val_accuracy: 0.0599
# Epoch 24/100
# 9/9 [==============================] - 2s 179ms/step - loss: 3.1620 - accuracy: 0.0759 - val_loss: 3.1359 - val_accuracy: 0.0599
# Epoch 25/100
# 9/9 [==============================] - 2s 182ms/step - loss: 3.1609 - accuracy: 0.0749 - val_loss: 3.1360 - val_accuracy: 0.0599
# Epoch 26/100
# 9/9 [==============================] - 2s 181ms/step - loss: 3.1616 - accuracy: 0.0742 - val_loss: 3.1351 - val_accuracy: 0.0599
# Epoch 27/100
# 9/9 [==============================] - 2s 220ms/step - loss: 3.1624 - accuracy: 0.0749 - val_loss: 3.1351 - val_accuracy: 0.0599
# Epoch 28/100
# 9/9 [==============================] - 2s 238ms/step - loss: 3.1610 - accuracy: 0.0757 - val_loss: 3.1363 - val_accuracy: 0.0599
# Epoch 29/100
# 9/9 [==============================] - 2s 231ms/step - loss: 3.1626 - accuracy: 0.0747 - val_loss: 3.1367 - val_accuracy: 0.0599
# Epoch 30/100
# 9/9 [==============================] - 2s 227ms/step - loss: 3.1607 - accuracy: 0.0754 - val_loss: 3.1364 - val_accuracy: 0.0599
# Epoch 31/100
# 9/9 [==============================] - 2s 221ms/step - loss: 3.1612 - accuracy: 0.0747 - val_loss: 3.1343 - val_accuracy: 0.0599
# Epoch 32/100
# 9/9 [==============================] - 2s 219ms/step - loss: 3.1619 - accuracy: 0.0747 - val_loss: 3.1353 - val_accuracy: 0.0599
# Epoch 33/100
# 9/9 [==============================] - 2s 228ms/step - loss: 3.1611 - accuracy: 0.0739 - val_loss: 3.1360 - val_accuracy: 0.0599
# Epoch 34/100
# 9/9 [==============================] - 2s 225ms/step - loss: 3.1618 - accuracy: 0.0744 - val_loss: 3.1354 - val_accuracy: 0.0599
# Epoch 35/100
# 9/9 [==============================] - 2s 218ms/step - loss: 3.1607 - accuracy: 0.0737 - val_loss: 3.1359 - val_accuracy: 0.0599
# Epoch 36/100
# 9/9 [==============================] - 2s 222ms/step - loss: 3.1617 - accuracy: 0.0732 - val_loss: 3.1377 - val_accuracy: 0.0599
# Epoch 37/100
# 9/9 [==============================] - 2s 185ms/step - loss: 3.1613 - accuracy: 0.0744 - val_loss: 3.1377 - val_accuracy: 0.0599
# Epoch 38/100
# 9/9 [==============================] - 2s 182ms/step - loss: 3.1614 - accuracy: 0.0747 - val_loss: 3.1362 - val_accuracy: 0.0599
# Epoch 39/100
# 9/9 [==============================] - 2s 184ms/step - loss: 3.1619 - accuracy: 0.0744 - val_loss: 3.1370 - val_accuracy: 0.0599
# Epoch 40/100
# 9/9 [==============================] - 2s 177ms/step - loss: 3.1614 - accuracy: 0.0744 - val_loss: 3.1369 - val_accuracy: 0.0599
# Epoch 41/100
# 9/9 [==============================] - 2s 170ms/step - loss: 3.1594 - accuracy: 0.0744 - val_loss: 3.1365 - val_accuracy: 0.0599
# Epoch 42/100
# 9/9 [==============================] - 2s 168ms/step - loss: 3.1622 - accuracy: 0.0747 - val_loss: 3.1361 - val_accuracy: 0.0599
# Epoch 43/100
# 9/9 [==============================] - 2s 169ms/step - loss: 3.1624 - accuracy: 0.0749 - val_loss: 3.1365 - val_accuracy: 0.0599
# Epoch 44/100
# 9/9 [==============================] - 2s 179ms/step - loss: 3.1620 - accuracy: 0.0752 - val_loss: 3.1375 - val_accuracy: 0.0599
# Epoch 45/100
# 9/9 [==============================] - 2s 179ms/step - loss: 3.1626 - accuracy: 0.0742 - val_loss: 3.1378 - val_accuracy: 0.0599
# Epoch 46/100
# 9/9 [==============================] - 2s 179ms/step - loss: 3.1622 - accuracy: 0.0742 - val_loss: 3.1376 - val_accuracy: 0.0599
# Epoch 47/100
# 9/9 [==============================] - 2s 171ms/step - loss: 3.1610 - accuracy: 0.0747 - val_loss: 3.1369 - val_accuracy: 0.0599
# Epoch 48/100
# 9/9 [==============================] - 2s 171ms/step - loss: 3.1606 - accuracy: 0.0739 - val_loss: 3.1349 - val_accuracy: 0.0599
# Epoch 49/100
# 9/9 [==============================] - 2s 168ms/step - loss: 3.1624 - accuracy: 0.0737 - val_loss: 3.1347 - val_accuracy: 0.0599
# Epoch 50/100
# 9/9 [==============================] - 2s 176ms/step - loss: 3.1605 - accuracy: 0.0744 - val_loss: 3.1352 - val_accuracy: 0.0599
# Epoch 51/100
# 9/9 [==============================] - 2s 180ms/step - loss: 3.1612 - accuracy: 0.0754 - val_loss: 3.1348 - val_accuracy: 0.0599
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1352 - accuracy: 0.0840
# =============================================
# Current Accuracy: 0.0840 | Best Accuracy: 0.1260
# Current Loss: 3.1352 | Best Loss: 3.4386
# =============================================

# %%
best_model.save(path_to_model)

# %%
print(f"Best accuracy: {best_acc:.2f}%")
print(f"Best loss: {best_loss:.2f}%")
# Out:
# Best accuracy: 5.34%
# Best loss: 0.32%

# %%
if best_history:
    plot_accuracy(best_history)
    plot_loss(best_history)
else:
    print("No history to plot")

# %%
keras.backend.clear_session()
print("Loading the model..")
best_model = keras.models.load_model(path_to_model)

if best_model is not None:
    print("Model loaded!")
    best_model: keras.models.Model
else:
    raise ValueError("Failed to load the model from the specified path.")
# Out:
# Loading the model..
# Model loaded!

# %%
def display_confusion_matrix(real: list[int], predicted: list[int]):
    cmap = "viridis"
    cm_plot_labels = [i for i in range(25)]

    cm = metrics.confusion_matrix(y_true=real, y_pred=predicted)
    df_cm = pd.DataFrame(cm, cm_plot_labels, cm_plot_labels)
    sns.set(font_scale=1.1)
    plt.figure(figsize=(15, 10))
    s = sns.heatmap(df_cm, annot=True, cmap=cmap)
    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    plt.savefig(f"{ARTIFACT_DIR}/metrics/confusion_matrix.png")
    plt.show()

# %%
if best_model:
    Y_pred = best_model.predict(X_test)

    Y_pred_classes = np.argmax(Y_pred, axis=1)
    Y_true = np.argmax(Y_test, axis=1)

    display_confusion_matrix(Y_true, Y_pred_classes)
else:
    print("No best model found.")
# Out:
# No best model found.
